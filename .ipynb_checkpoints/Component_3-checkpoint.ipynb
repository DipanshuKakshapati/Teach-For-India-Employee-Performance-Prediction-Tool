# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Test_Data.csv')
df
# Out:
#        employee_id         department     region         education gender  \
# 0             8724         Technology  region_26        Bachelor's      m
# 1            74430                 HR   region_4        Bachelor's      f
# 2            72255  Sales & Marketing  region_13        Bachelor's      m
# 3            38562        Procurement   region_2        Bachelor's      f
# 4            64486            Finance  region_29        Bachelor's      m
# ...            ...                ...        ...               ...    ...
# 23485        53478              Legal   region_2   Below Secondary      m
# 23486        25600         Technology  region_25        Bachelor's      m
# 23487        45409                 HR  region_16        Bachelor's      f
# 23488         1186        Procurement  region_31        Bachelor's      m
# 23489         5973         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   NaN
# 1                   other                1   31                   3.0
# 2                   other                1   31                   1.0
# 3                   other                3   31                   2.0
# 4                sourcing                1   30                   4.0
# ...                   ...              ...  ...                   ...
# 23485            sourcing                1   24                   3.0
# 23486            sourcing                1   31                   3.0
# 23487            sourcing                1   26                   4.0
# 23488            sourcing                3   27                   NaN
# 23489               other                3   40                   5.0
#
#        length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                      1              1            0                  77
# 1                      5              0            0                  51
# 2                      4              0            0                  47
# 3                      9              0            0                  65
# 4                      7              0            0                  61
# ...                  ...            ...          ...                 ...
# 23485                  1              0            0                  61
# 23486                  7              0            0                  74
# 23487                  4              0            0                  50
# 23488                  1              0            0                  70
# 23489                  5              1            0                  89
#
# [23490 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23490 entries, 0 to 23489
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           23490 non-null  int64
#  1   department            23490 non-null  object
#  2   region                23490 non-null  object
#  3   education             22456 non-null  object
#  4   gender                23490 non-null  object
#  5   recruitment_channel   23490 non-null  object
#  6   no_of_trainings       23490 non-null  int64
#  7   age                   23490 non-null  int64
#  8   previous_year_rating  21678 non-null  float64
#  9   length_of_service     23490 non-null  int64
#  10  KPIs_met >80%         23490 non-null  int64
#  11  awards_won?           23490 non-null  int64
#  12  avg_training_score    23490 non-null  int64
# dtypes: float64(1), int64(7), object(5)
# memory usage: 2.3+ MB

# %%
df.isnull().sum()
# Out:
# employee_id                0
# department                 0
# region                     0
# education               1034
# gender                     0
# recruitment_channel        0
# no_of_trainings            0
# age                        0
# previous_year_rating    1812
# length_of_service          0
# KPIs_met >80%              0
# awards_won?                0
# avg_training_score         0
# dtype: int64

# %%
education_value_counts=df['education'].value_counts()

# %%
education_value_counts.plot(kind='bar', rot=25)
plt.ylabel('Value Counts')
plt.show()

# %%
def treat_null_in_education(df, col_name):
    df[col_name] = df[col_name].fillna('Others')

treat_null_in_education(df, 'education')

# %%
new_education_value_counts = df['education'].value_counts()

# %%
new_education_value_counts.plot(kind='bar', rot=30)
plt.ylabel('Value Counts')
plt.show()

# %%
rating_value_counts = df['previous_year_rating'].value_counts()

# %%
rating_value_counts.plot(kind='bar', rot=0)
plt.show()

# %%
mode_value = df['previous_year_rating'].mode()[0]
df['previous_year_rating'].fillna(mode_value, inplace=True)

# %%
filled_rating_value_counts=df['previous_year_rating'].value_counts()

# %%
filled_rating_value_counts.plot(kind='bar', rot=0)
plt.ylabel('Value Counts')
plt.show()

# %%
df.isnull().sum()
# Out:
# employee_id             0
# department              0
# region                  0
# education               0
# gender                  0
# recruitment_channel     0
# no_of_trainings         0
# age                     0
# previous_year_rating    0
# length_of_service       0
# KPIs_met >80%           0
# awards_won?             0
# avg_training_score      0
# dtype: int64

# %%
department_value_counts = df['department'].value_counts()

# %%
plt.figure(figsize=(15, 5))
department_value_counts.plot(kind='bar', rot=30)
plt.ylabel('Value Counts')
plt.show()

# %%
region_value_counts = df['region'].value_counts()

# %%
plt.figure(figsize=(15, 5))
region_value_counts.plot(kind='bar')
plt.ylabel('Value Counts')
plt.show()

# %%
gender_value_counts = df['gender'].value_counts()

# %%
gender_value_counts.plot(kind='bar', rot=0)
plt.ylabel('Value Counts')
plt.show()

# %%
recruitment_value_counts = df['recruitment_channel'].value_counts()

# %%
recruitment_value_counts.plot(kind='bar', rot=0)
plt.ylabel('Value Counts')
plt.show()

# %%
trainings_value_counts = df['no_of_trainings'].value_counts()

# %%
trainings_value_counts.plot(kind='bar', rot=0)
plt.ylabel('Value Counts')
plt.show()

# %%
age_value_counts = df['age'].value_counts()

# %%
plt.figure(figsize=(15,5))
age_value_counts.plot(kind='bar', rot=0)
plt.ylabel('Value Counts')
plt.show()

# %%
service_value_counts = df['length_of_service'].value_counts()

# %%
plt.figure(figsize=(15,5))
service_value_counts.plot(kind='bar', rot=0)
plt.ylabel('Value Counts')
plt.show()

# %%
def more_than_10(value):
    if value > 10:
        return 'LoS More Than 11'
    else:
        return value  # or '10 or Less' or any other label you want to use for values 10 or below

# Apply the function to the 'length_of_service' column
df['length_of_service'] = df['length_of_service'].apply(more_than_10)

service_value_counts = df['length_of_service'].value_counts()

# %%
plt.figure(figsize=(15,5))
service_value_counts.plot(kind='bar', rot=0)
plt.ylabel('Value Counts')
plt.show()

# %%
kpi_value_counts = df['KPIs_met >80%'].value_counts()

# %%
kpi_value_counts.plot(kind='bar', rot=0)
plt.ylabel('Value Counts')
plt.show()

# %%
awards_value_counts = df['awards_won?'].value_counts()

# %%
awards_value_counts.plot(kind='bar', rot=0)
plt.ylabel('Value Counts')
plt.show()

# %%
df['avg_training_score'].value_counts()
# Out:
# avg_training_score
# 50    1227
# 49    1144
# 48    1084
# 51    1023
# 60     889
#       ...
# 98      14
# 99      13
# 41      11
# 40       3
# 39       1
# Name: count, Length: 61, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23490 entries, 0 to 23489
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   employee_id           23490 non-null  int64
#  1   department            23490 non-null  object
#  2   region                23490 non-null  object
#  3   education             23490 non-null  object
#  4   gender                23490 non-null  object
#  5   recruitment_channel   23490 non-null  object
#  6   no_of_trainings       23490 non-null  int64
#  7   age                   23490 non-null  int64
#  8   previous_year_rating  23490 non-null  float64
#  9   length_of_service     23490 non-null  object
#  10  KPIs_met >80%         23490 non-null  int64
#  11  awards_won?           23490 non-null  int64
#  12  avg_training_score    23490 non-null  int64
# dtypes: float64(1), int64(6), object(6)
# memory usage: 2.3+ MB

# %%
df.drop(columns=['employee_id'])
# Out:
#               department     region         education gender  \
# 0             Technology  region_26        Bachelor's      m
# 1                     HR   region_4        Bachelor's      f
# 2      Sales & Marketing  region_13        Bachelor's      m
# 3            Procurement   region_2        Bachelor's      f
# 4                Finance  region_29        Bachelor's      m
# ...                  ...        ...               ...    ...
# 23485              Legal   region_2   Below Secondary      m
# 23486         Technology  region_25        Bachelor's      m
# 23487                 HR  region_16        Bachelor's      f
# 23488        Procurement  region_31        Bachelor's      m
# 23489         Technology  region_17  Master's & above      m
#
#       recruitment_channel  no_of_trainings  age  previous_year_rating  \
# 0                sourcing                1   24                   3.0
# 1                   other                1   31                   3.0
# 2                   other                1   31                   1.0
# 3                   other                3   31                   2.0
# 4                sourcing                1   30                   4.0
# ...                   ...              ...  ...                   ...
# 23485            sourcing                1   24                   3.0
# 23486            sourcing                1   31                   3.0
# 23487            sourcing                1   26                   4.0
# 23488            sourcing                3   27                   3.0
# 23489               other                3   40                   5.0
#
#       length_of_service  KPIs_met >80%  awards_won?  avg_training_score
# 0                     1              1            0                  77
# 1                     5              0            0                  51
# 2                     4              0            0                  47
# 3                     9              0            0                  65
# 4                     7              0            0                  61
# ...                 ...            ...          ...                 ...
# 23485                 1              0            0                  61
# 23486                 7              0            0                  74
# 23487                 4              0            0                  50
# 23488                 1              0            0                  70
# 23489                 5              1            0                  89
#
# [23490 rows x 12 columns]
